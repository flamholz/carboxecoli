# %%
from cobra.io import read_sbml_model
import matplotlib.pyplot as plt
import os
import sys
import optslope

wt_model = optslope.create_extended_core_model()

fig1 = optslope.plot_production_envelope(
    wt_model,
    knockouts=[ ],
    carbon_sources=["glc__D"],
    target_reaction="EX_ac_e")
fig1.axes[0].set_title("wild-type")

fig2 = optslope.plot_production_envelope(
    wt_model,
    knockouts=["TPI", ],
    carbon_sources=["glc__D"],
    target_reaction="EX_ac_e")
fig2.axes[0].set_title("Δtpi");
